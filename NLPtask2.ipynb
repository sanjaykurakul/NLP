# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjaykurakul/NLP/blob/main/NLPtask2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk transformers torch

import nltk
from nltk.tokenize import word_tokenize
from transformers import AutoTokenizer
nltk.download("punkt")
nltk.download("punkt_tab")
text = "Tokenization without transformers is straightforward with tools like NLTK."
tokens = word_tokenize(text)
print("NLTK Tokens:")
print(tokens)
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
tokens_transformers = tokenizer(
    text,
    return_tensors="pt"
)
print("\nTransformers Output:")
print(tokens_transformers)
input_ids = tokens_transformers["input_ids"][0]

tokens_transformers_list = tokenizer.convert_ids_to_tokens(
    input_ids.tolist()
)

print("\nTransformers Tokens (List):")
print(tokens_transformers_list)
decoded_text = tokenizer.decode(
    input_ids,
    skip_special_tokens=True
)
print("\nDecoded Text:")
print(decoded_text)
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# NLTK Tokens:
# ['Tokenization', 'without', 'transformers', 'is', 'straightforward', 'with', 'tools', 'like', 'NLTK', '.']
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Transformers Output:
# {'input_ids': tensor([[  101, 19204,  3989,  2302, 19081,  2003, 19647,  2007,  5906,  2066,
# ...
